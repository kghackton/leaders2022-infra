# %%
import pandas as pd
import sqlalchemy
import psycopg2
# import dask.dataframe as dd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
path = "./Full_16_09_22.csv"

# %%
def change_columns(df, naming_path="naming.csv") -> pd.DataFrame:
    '''
    Function which changes column names for pd.DataFrame
    '''
    
    new_names = list(
        map(
            lambda x: x.strip(),
            list(pd.read_csv(naming_path)['new_name'])
        )
    )
    df.columns = new_names

    return df

# %%
df = change_columns(pd.read_csv(path, nrows=500, sep='$', index_col=False))

# %%
id_features = [
    "root_id",
    "version_id",
    "request_number",
    "mos_ru_request_number",
    "root_identificator_of_maternal",
    "number_of_maternal",
    "deffect_category_id",
    "deffect_id",
    "district_code",
    "hood_code",
    "performing_company",
    "inn_of_performing_company",
    "id_of_reason_for_decline", # all values are NaN in taken sample
    "id_of_reason_for_decline_of_org",   # all values are NaN in taken sample
    "id_work_type_done",
    "id_guarding_events"
]

date_features = [
    "date_of_creation",
    "date_of_start",
    "wanted_time_from",
    "wanted_time_to",
    "date_of_review",
    "date_of_last_return_for_revision",
    "closure_date"
]

# All numerical features are discrete -> casting to Int64
numerical_features = [
    "times_returned",    # might be useful
    "adress_unom"
]

categorical_features = [
    "name_of_source",
    "name_of_source_eng",
    "name_of_creator",
    "role_of_user",
    "deffect_category_name",
    "deffect_category_name_eng",
    "deffect_name",
    "short_deffect_name",
    "need_for_revision",
    "urgency_category",
    "urgency_category_eng",
    "district",
    "hood",
    "adress_of_problem",
    "incident_feature",
    "serving_company",
    "dispetchers_number",
    "request_status",
    "request_status_eng",
    "reason_for_decline",   # all values are NaN in taken sample
    "reason_for_decline_of_org", # all values are NaN in taken sample
    "efficiency",
    "efficiency_eng",
    "being_on_revision",
    "alerted_feature",
    "grade_for_service",
    "grade_for_service_eng",
    "payment_category",
    "payment_category_eng",
    "payed_by_card"
]

# String features can also be categorical with a lot of possible values
string_features = [
    "last_name_redacted",
    "commentaries", # might be useful
    "code_of_deffect",
    "description",  # might be useful
    "presence_of_question", # might be useful

    "dispetchers_number",
    "owner_company",
    "work_type_done", # might be useful
    "used_material",
    "guarding_events", # might be useful
    "review",    # might be useful - here is the information about the results of the work

    # These are numerical features, that include some strangely filled rows:
    "floor",
    "flat_number",
    "porch",
]

useful_features = ["times_returned", "commentaries", "description", "presence_of_question", "work_type_done", "guarding_events", "review"]

# %%
# Проверяю, что не забыл никакого столба:
for feat in list(df.columns):
    if feat not in (string_features + categorical_features + numerical_features + id_features + date_features):
        print(feat)

# %%
df.isna().sum()
# Out:
# root_id                               0
# version_id                            0
# request_number                        0
# mos_ru_request_number               445
# date_of_creation                      0
# date_of_start                         0
# name_of_source                        0
# name_of_source_eng                    0
# name_of_creator                       0
# incident_feature                      0
# root_identificator_of_maternal      485
# number_of_maternal                  485
# last_name_redacted                    0
# role_of_user                          0
# commentaries                         98
# deffect_category_name                 0
# deffect_category_id                   0
# deffect_category_name_eng           432
# deffect_name                          0
# short_deffect_name                    0
# deffect_id                            0
# code_of_deffect                       0
# need_for_revision                     0
# description                           6
# presence_of_question                493
# urgency_category                      0
# urgency_category_eng                  0
# district                              0
# district_code                         0
# hood                                  0
# hood_code                             0
# adress_of_problem                     0
# adress_unom                           0
# porch                                 6
# floor                               107
# flat_number                         117
# dispetchers_number                    0
# owner_company                         1
# serving_company                      11
# performing_company                   11
# inn_of_performing_company           338
# request_status                        0
# request_status_eng                    0
# reason_for_decline                  500
# id_of_reason_for_decline            500
# reason_for_decline_of_org           500
# id_of_reason_for_decline_of_org     500
# work_type_done                        0
# id_work_type_done                     0
# used_material                       495
# guarding_events                     397
# id_guarding_events                  397
# efficiency                            0
# efficiency_eng                        0
# times_returned                      500
# date_of_last_return_for_revision    500
# being_on_revision                     0
# alerted_feature                       0
# closure_date                          0
# wanted_time_from                    411
# wanted_time_to                      411
# date_of_review                      411
# review                              415
# grade_for_service                   411
# grade_for_service_eng               411
# payment_category                      0
# payment_category_eng                  0
# payed_by_card                         0
# dtype: int64

# %%
# Изменение типов колонок:
def cast_types(df) -> pd.DataFrame:

    to_str = string_features + categorical_features + id_features

    for feature in to_str:
        df = df.astype({
            feature: "object"
        })

    for feature in numerical_features:
        df = df.astype({
            feature: "Int64"
        })

    for feature in date_features:
        df = df.astype({
            feature: "datetime64[ns]"   # if the time precission is given up to ns - that's the format
        })
    
    return df

df = cast_types(df)

# %%
# Очень важно, чтобы при касте типов сохранилось исходное количество NaN и они не прочитались как строки:
df.isna().sum()
# Out:
# root_id                               0
# version_id                            0
# request_number                        0
# mos_ru_request_number               445
# date_of_creation                      0
# date_of_start                         0
# name_of_source                        0
# name_of_source_eng                    0
# name_of_creator                       0
# incident_feature                      0
# root_identificator_of_maternal      485
# number_of_maternal                  485
# last_name_redacted                    0
# role_of_user                          0
# commentaries                         98
# deffect_category_name                 0
# deffect_category_id                   0
# deffect_category_name_eng           432
# deffect_name                          0
# short_deffect_name                    0
# deffect_id                            0
# code_of_deffect                       0
# need_for_revision                     0
# description                           6
# presence_of_question                493
# urgency_category                      0
# urgency_category_eng                  0
# district                              0
# district_code                         0
# hood                                  0
# hood_code                             0
# adress_of_problem                     0
# adress_unom                           0
# porch                                 6
# floor                               107
# flat_number                         117
# dispetchers_number                    0
# owner_company                         1
# serving_company                      11
# performing_company                   11
# inn_of_performing_company           338
# request_status                        0
# request_status_eng                    0
# reason_for_decline                  500
# id_of_reason_for_decline            500
# reason_for_decline_of_org           500
# id_of_reason_for_decline_of_org     500
# work_type_done                        0
# id_work_type_done                     0
# used_material                       495
# guarding_events                     397
# id_guarding_events                  397
# efficiency                            0
# efficiency_eng                        0
# times_returned                      500
# date_of_last_return_for_revision    500
# being_on_revision                     0
# alerted_feature                       0
# closure_date                          0
# wanted_time_from                    411
# wanted_time_to                      411
# date_of_review                      411
# review                              415
# grade_for_service                   411
# grade_for_service_eng               411
# payment_category                      0
# payment_category_eng                  0
# payed_by_card                         0
# dtype: int64

# %%
df.info(null_counts=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 68 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   root_id                           object
#  1   version_id                        object
#  2   request_number                    object
#  3   mos_ru_request_number             object
#  4   date_of_creation                  datetime64[ns]
#  5   date_of_start                     datetime64[ns]
#  6   name_of_source                    object
#  7   name_of_source_eng                object
#  8   name_of_creator                   object
#  9   incident_feature                  object
#  10  root_identificator_of_maternal    object
#  11  number_of_maternal                object
#  12  last_name_redacted                object
#  13  role_of_user                      object
#  14  commentaries                      object
#  15  deffect_category_name             object
#  16  deffect_category_id               object
#  17  deffect_category_name_eng         object
#  18  deffect_name                      object
#  19  short_deffect_name                object
#  20  deffect_id                        object
#  21  code_of_deffect                   object
#  22  need_for_revision                 object
#  23  description                       object
#  24  presence_of_question              object
#  25  urgency_category                  object
#  26  urgency_category_eng              object
#  27  district                          object
#  28  district_code                     object
#  29  hood                              object
#  30  hood_code                         object
#  31  adress_of_problem                 object
#  32  adress_unom                       Int64
#  33  porch                             object
#  34  floor                             object
#  35  flat_number                       object
#  36  dispetchers_number                object
#  37  owner_company                     object
#  38  serving_company                   object
#  39  performing_company                object
#  40  inn_of_performing_company         object
#  41  request_status                    object
#  42  request_status_eng                object
#  43  reason_for_decline                object
#  44  id_of_reason_for_decline          object
#  45  reason_for_decline_of_org         object
#  46  id_of_reason_for_decline_of_org   object
#  47  work_type_done                    object
#  48  id_work_type_done                 object
#  49  used_material                     object
#  50  guarding_events                   object
#  51  id_guarding_events                object
#  52  efficiency                        object
#  53  efficiency_eng                    object
#  54  times_returned                    Int64
#  55  date_of_last_return_for_revision  datetime64[ns]
#  56  being_on_revision                 object
#  57  alerted_feature                   object
#  58  closure_date                      datetime64[ns]
#  59  wanted_time_from                  datetime64[ns]
#  60  wanted_time_to                    datetime64[ns]
#  61  date_of_review                    datetime64[ns]
#  62  review                            object
#  63  grade_for_service                 object
#  64  grade_for_service_eng             object
#  65  payment_category                  object
#  66  payment_category_eng              object
#  67  payed_by_card                     object
# dtypes: Int64(2), datetime64[ns](7), object(59)
# memory usage: 266.7+ KB
# /var/folders/wd/hzhqgvf53nx31yb883qxnmdw0000gn/T/ipykernel_15642/797607940.py:1: FutureWarning: null_counts is deprecated. Use show_counts instead
#   df.info(null_counts=False)

# %% [markdown]
# ---
# # SQL querying:

# %%
import json
from sqlalchemy.sql import text
from sqlalchemy.types import Integer, Text, String, DateTime, VARCHAR

# %%
url_path = "./db_url.json"
with open(url_path) as json_file:
    dic = json.load(json_file)

url = dic["dialect+driver"] + "://" + dic["username"] + ":" + dic["password"] + "@" + dic["host"] + ":" + dic["port"] + "/" + dic["database"]

# %%
engine = sqlalchemy.create_engine(url)

# %%
dtype = {}
for feature in string_features + categorical_features + id_features:
    dtype[feature] = VARCHAR
for feature in numerical_features:
    dtype[feature] = Integer
for feature in date_features:
    dtype[feature] = DateTime

def write_into_db(df, dtype, if_exists="append", name="requests", bd_chunksize=1000) -> None:
    '''
    Functions which writes pd.DataFrame into DB

    if_exists: append/replace/fail
    '''
    df.to_sql(
    name, 
    con = engine,
    if_exists = if_exists,   
    index=False,
    chunksize=bd_chunksize,
    dtype = dtype
    )

# %%
# !!!!! ТЕСТОВЫЙ ЗАПУСК - ПЕРЕЗАПИСЬ ВСЕЙ БД !!!!!

# write_into_db(df, dtype, if_exists='replace')

# %% [markdown]
# ---
# ## Scaling of the whole process with a use of batch-reading:

# %%
from tqdm import tqdm

# %%
def write_by_chunks_into_db(path, engine, iterator_chunksize=5000, bd_chunksize=1000, steps=1, replace_all_data=False, skip_amount=0) -> None:
    '''
    добавление в бд iterator_chunksize * steps строк

    path: 'global' path to huge csv file
    steps: количество шагов
    iterator_chunksize: размер чанка для 1 кусочка таблицы
    bd_chunksize: сколько за раз записывается в бд

    skip_amount: сколько строчек надо скипнуть и потом начать записывать

    '''
    wrote_smth_into_db = False

    # Последовательно можно доставать куски:
    df_iterator = pd.read_csv(
        path,
        sep='$',
        chunksize=iterator_chunksize,
        low_memory=False
    )
    for chunk_number, chunk in tqdm(enumerate(df_iterator), desc="Iter: "):
        
        chunk = cast_types(change_columns(chunk))

        if skip_amount and ((chunk_number + 1) * iterator_chunksize <= skip_amount or chunk_number == 0):
            continue

        if not wrote_smth_into_db and replace_all_data:
            write_into_db(chunk, dtype=dtype, if_exists='replace', bd_chunksize=bd_chunksize)
            wrote_smth_into_db = True
        else:
            write_into_db(chunk, dtype=dtype, if_exists='append', bd_chunksize=bd_chunksize)
            
        if chunk_number >= steps - 1:
            return

# %%
write_by_chunks_into_db(
    path,
    engine,

    iterator_chunksize=20000,
    steps=80,   # здесь надо учитывать skip_amount: Если надо закинуть N строк, скипнув M строк, то: steps * iterator_chunksize == M + N

    bd_chunksize=20000,

    # replace_all_data=False,

    skip_amount = 1000000 + 200000
)

# %%
1000000 / 20000
# Out:
# 50.0
